# %%
import pandas as pd
import matplotlib as py
import numpy as np
import seaborn as sms

# %%
Polynomial = np.polynomial.Polynomial

p = Polynomial([6,-5, 1])

q = Polynomial([2, -3])

# %%
print(p)

print(q)
# Out:
# 6.0 - 5.0 x**1 + 1.0 x**2
# 2.0 - 3.0 x**1

# %%
sms.relplot(x = 'Data.AIDS-Related Deaths.All Ages', y = 'Data.HIV Prevalence.Adults', hue = 'Country', aids = dataset )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7036/2913978247.py in <module>
# ----> 1 sms.relplot(x = 'Data.AIDS-Related Deaths.All Ages', y = 'Data.HIV Prevalence.Adults', hue = 'Country', aids = dataset )
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     945
#     946     # Use the full dataset to map the semantics
# --> 947     p = plotter(
# ...

# %%
dataset = pd.read_csv("C:/Users/Hp/Downloads/aids.csv")

# %%
dataset
# Out:
#                                  Country  Year  \
# 0                            Afghanistan  1990
# 1                                Algeria  1990
# 2                                 Angola  1990
# 3                              Argentina  1990
# 4                                Armenia  1990
# ...                                  ...   ...
# 2754  Venezuela (Bolivarian Republic of)  2020
# 2755                            Viet Nam  2020
# 2756                               Yemen  2020
# 2757                              Zambia  2020
# 2758                            Zimbabwe  2020
#
#       Data.AIDS-Related Deaths.AIDS Orphans  Data.AIDS-Related Deaths.Adults  \
# 0                                       100                              100
# 1                                       200                              100
# 2                                      1300                              500
# 3                                       500                              200
# ...

# %%
dataset.describe()
# Out:
#               Year  Data.AIDS-Related Deaths.AIDS Orphans  \
# count  2759.000000                           2.759000e+03
# mean   2005.000000                           1.042936e+05
# std       8.945893                           2.437087e+05
# min    1990.000000                           1.000000e+02
# 25%    1997.000000                           1.200000e+03
# 50%    2005.000000                           1.200000e+04
# 75%    2013.000000                           6.600000e+04
# max    2020.000000                           1.800000e+06
#
#        Data.AIDS-Related Deaths.Adults  Data.AIDS-Related Deaths.All Ages  \
# count                      2759.000000                        2759.000000
# mean                       7755.164915                       10171.801377
# std                       18358.408671                       23381.648703
# min                         100.000000                         100.000000
# ...

# %%
dataset.isnull()
# Out:
#       Country   Year  Data.AIDS-Related Deaths.AIDS Orphans  \
# 0       False  False                                  False
# 1       False  False                                  False
# 2       False  False                                  False
# 3       False  False                                  False
# 4       False  False                                  False
# ...       ...    ...                                    ...
# 2754    False  False                                  False
# 2755    False  False                                  False
# 2756    False  False                                  False
# 2757    False  False                                  False
# 2758    False  False                                  False
#
#       Data.AIDS-Related Deaths.Adults  Data.AIDS-Related Deaths.All Ages  \
# 0                               False                              False
# 1                               False                              False
# ...

# %%
sms.relplot(x = 'Data.AIDS-Related Deaths.All Ages', y = 'Data.HIV Prevalence.Adults', hue = 'Country', data = dataset)

# %% [markdown]
# **Datascience first practise**

# %%
dataset['Data.New HIV Infections.Incidence Rate Among Adults'].unique()
# Out:
# array([1.000e-02, 4.700e-01, 1.900e-01, 1.600e+00, 6.000e-02, 2.216e+01,
#        3.740e+00, 7.850e+00, 5.000e-02, 2.320e+00, 2.210e+00, 3.500e-01,
#        8.110e+00, 1.000e-01, 2.000e-02, 1.026e+01, 2.160e+00, 3.800e-01,
#        1.550e+00, 1.700e-01, 1.100e-01, 1.960e+00, 5.550e+00, 4.310e+00,
#        2.830e+00, 4.300e-01, 2.990e+00, 2.700e-01, 1.190e+00, 7.100e-01,
#        8.000e-02, 4.470e+00, 1.270e+00, 1.400e+00, 1.434e+01, 7.040e+00,
#        3.970e+00, 1.791e+01, 4.400e-01, 2.550e+00, 4.000e-02, 3.470e+00,
#        6.270e+00, 3.000e-02, 4.200e-01, 1.250e+00, 1.600e-01, 4.600e-01,
#        5.030e+00, 3.600e-01, 1.380e+00, 2.530e+00, 1.530e+00, 3.630e+00,
#        2.730e+00, 1.055e+01, 8.030e+00, 9.000e-02, 1.986e+01, 3.958e+01,
#        5.600e-01, 2.200e-01, 1.760e+00, 7.000e-02, 2.994e+01, 3.220e+00,
#        7.020e+00, 1.400e-01, 2.960e+00, 2.590e+00, 4.000e-01, 7.390e+00,
#        1.138e+01, 2.200e+00, 6.900e-01, 1.910e+00, 2.000e-01, 1.500e-01,
# ...

# %%
dataset['Data.HIV Prevalence.Adults'].unique()
# Out:
# array([ 0.1,  0.2,  0.8,  5.7,  2.6,  4.1,  1. ,  3.8,  1.3,  0.5,  0.9,
#         1.1,  1.6,  1.2,  2.3,  0.6,  0.7,  4.8,  1.8,  1.5,  8.2,  1.9,
#         2.2, 10.1,  3.4, 14.5,  8.3,  2.8,  4.5,  4.6,  2.1,  2. ,  0.3,
#         6.2,  2.9,  9.5,  1.4,  2.7,  4. ,  9.6, 17.5, 11.4,  4.9,  5.4,
#         2.4,  7.5, 10.8,  3.7,  3. , 10.9, 20.1,  0.4, 14.6,  5. ,  5.1,
#         1.7,  6.3,  8.6,  6.9,  2.5, 12. ,  9.9, 22.1, 17.7,  6.7,  9.2,
#         3.1, 13.1,  6.5,  3.9,  9.8, 12.8, 23.5, 20.5,  7.2, 12.3,  3.2,
#        10. , 12.5, 14. ,  5.3, 13.4, 24.4, 22.7,  4.7,  7.4, 15.1,  4.3,
#        15.2, 14.7,  9.3,  5.9, 13.7, 24.7, 24.3,  4.4,  3.6, 17.4,  5.8,
#        11.2,  9. ,  6.1, 13.9, 25.4,  4.2, 19.3,  5.2, 19.2, 15.3,  3.5,
#         8.7, 26. ,  7.3, 20.8,  7.6,  8.4, 23.6, 26.3,  7. ,  3.3, 21.9,
#         5.6,  9.1, 21.4, 14.9,  8.5, 13.6, 12.1,  8.1, 22.8, 26.2, 22.9,
#        22. , 13.2,  7.9, 25.8,  5.5, 22.3, 14.1,  6. , 20.9, 25.3, 22.6,
# ...

# %%
dataset['Country'].unique()
# Out:
# array(['Afghanistan', 'Algeria', 'Angola', 'Argentina', 'Armenia',
#        'Azerbaijan', 'Benin', 'Bolivia (Plurinational State of)',
#        'Botswana', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Chad', 'Colombia', 'Congo', 'Costa Rica', 'Cuba', "Côte d'Ivoire",
#        'Democratic Republic of the Congo', 'Djibouti',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea',
#        'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Georgia', 'Ghana',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'Indonesia', 'Iran (Islamic Republic of)', 'Jamaica',
#        'Kazakhstan', 'Kenya', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Lesotho', 'Liberia', 'Libya',
#        'Madagascar', 'Malawi', 'Malaysia', 'Mali', 'Mauritius', 'Morocco',
#        'Mozambique', 'Namibia', 'Nepal', 'Nicaragua', 'Niger', 'Nigeria',
#        'Pakistan', 'Paraguay', 'Peru', 'Philippines', 'Portugal',
# ...

# %%
dataset['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
dataset['Data.AIDS-Related Deaths.AIDS Orphans'].unique()
# Out:
# array([    100,     200,    1300,     500,    2800,    1800,   16000,
#          14000,    4000,    1000,    3800,   28000,   49000,    1100,
#           1200,   30000,   10000,    2000,    7900,    2100,   36000,
#          57000,    4700,    6100,   37000,   17000,   11000,    2200,
#           9000,  190000,   56000,    5600,   44000,   68000,    1700,
#           3700,    3200,   22000,   20000,    5800,    3900,    5900,
#          40000,   62000,    1500,   43000,   15000,    2700,    3000,
#           1400,   76000,    6400,   50000,   21000,    1600,   19000,
#           2900,  250000,   79000,    6200,   63000,  100000,    2300,
#           4900,    5300,   29000,   27000,    8200,    5400,    1900,
#           8600,   78000,   60000,    3600,    4100,   83000,   99000,
#           8700,   13000,   66000,   26000,   18000,    4200,  310000,
#         110000,    6900,   87000,  140000,    3100,   38000,   35000,
# ...

# %%
dataset['Data.AIDS-Related Deaths.Adults'].unique()
# Out:
# array([   100,    500,    200,   1000,   3200,   2500,   6100,   9600,
#          6600,   2000,   7600,  11000,   1100,   1400,   7000,   1600,
#          2400,   1300,  31000,   8000,  14000,   4000,   3300,   8500,
#         12000,   9200,   2700,  13000,   9300,   2900,   2100,   3400,
#          1500,  36000,  15000,  20000,   4900,   4100,   1900,   3600,
#         16000,  17000,   2800,   2600,   5400,   4500,   1800,  42000,
#         27000,   5700,   4600,   4200,  23000,   2300,   3100,   8700,
#          7900,  47000,  25000,  18000,  35000,   6500,   3500,   1700,
#         19000,  21000,   5900,   5100,   5500,   1200,  51000,  30000,
#         43000,   4300,   7200,   6400,  22000,  26000,  39000,  29000,
#          7400,  55000,  53000,   6000,   3900,  28000,  24000,   8600,
#          6700,  49000,   3000,  34000,   9700,   4400,   5200,  32000,
#         58000,  62000,   7300,   8400,   7500,  10000,  33000,   6200,
# ...

# %%
dataset['Data.AIDS-Related Deaths.All Ages'].unique()
# Out:
# array([   100,   1000,    500,   7200,   5300,   1900,   1200,   1800,
#         10000,  17000,  14000,   3900,   3100,  18000,  19000,   2100,
#           200,   2900,  12000,   2700,   3300,   3700,  50000,  20000,
#         15000,  25000,   1300,   1600,   8500,   6400,   2600,   2300,
#         13000,   5100,   4000,  23000,   4100,  16000,   5700,   1100,
#          2400,  57000,  33000,   2500,   9800,   7600,   3500,   6500,
#          5000,  28000,   5800,   4700,   9100,   1400,   5900,  63000,
#         31000,  24000,  43000,   2000,   3600,  11000,   8600,  22000,
#         26000,  29000,   8000,   1500,   1700,  69000,  38000,  53000,
#          9600,   6200,  27000,  30000,  35000,   9700,   6900,  39000,
#          4800,   4200,   6000,  74000,  46000,   6600,   8100,   2200,
#         32000,  41000,   7900,  64000,  44000,   5500,   2800,   4500,
#         34000,  78000,  40000,   4300,   5200,  37000,  47000,   8700,
# ...

# %%
dataset['Data.AIDS-Related Deaths.Children'].unique()
# Out:
# array([  100,   500,  1000,  4000,  2800,   200,  3900,  6900,  7200,
#         1900,  1100, 10000,  8100,  1500,  5100,  1700,  1300, 19000,
#         6700, 11000,  4400,  3200,  1200,  4900,  7900,  9000,  2400,
#         1400, 13000,  9600,  2100,  6300,  2200, 20000,  9900,  8200,
#        14000,  3500,  6000,  8900,  2900, 17000,  7700,  3700, 21000,
#        12000, 16000,  1600,  5200,  3800,  7100,  3400,  9100,  5900,
#        22000, 18000,  2000,  5500,  1800, 23000,  8700,  2700, 15000,
#         2300,  5700,  4200, 25000,  6600,  2600,  3100, 24000,  5800,
#         9700,  4600, 27000, 28000,  9800,  2500,  3000,  6400,  5300,
#        29000,  3600, 26000,  7000,  5600,  7600, 33000,  4300,  5400,
#         3300, 35000,  4100, 39000,  5000,  8300, 43000,  4800,  8400,
#         9300, 46000,  4500,  8800, 49000,  4700, 41000,  9400, 32000,
#         7400,  7500,  6200,  6100,  8600,  6800,  8000], dtype=int64)

# %%
dataset['Data.AIDS-Related Deaths.Female Adults'].unique()
# Out:
# array([   100,    200,    500,   1600,   1100,   1000,   2600,   6800,
#          3400,   4100,   5800,   3100,   1200,  16000,   5500,   3900,
#          6400,   2000,   1500,   3700,   8300,   4800,   6200,   7500,
#          4200,   1700,  19000,   7600,   9400,   2400,   1900,   5100,
#         10000,   6700,   1400,   9100,   5600,   1300,   2800,  23000,
#          7300,  13000,   2900,  12000,   9000,   2700,   1800,   2300,
#          4600,  25000,   9500,  17000,   3300,   2100,   8700,  14000,
#          2200,   3200,   9200,   7400,  28000,  22000,  11000,   4300,
#          3500,  31000,  27000,   3800,  18000,   3000,  20000,   5000,
#         33000,  32000,   4000,   4400,   4900,   6100,  34000,   2500,
#         26000,  37000,  21000,   7000,  40000,  35000,  29000,  42000,
#          5900,   7900,  45000,  46000,   8800,  49000,  30000,   5300,
#         59000,  36000,   7700,   9600,  53000,  72000,  15000,  38000,
# ...
